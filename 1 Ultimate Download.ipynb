# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

# pip install numpy
# conda install -c anaconda pandas
# conda install -c conda-forge matplotlib

import datetime as dt # For defining dates

import time

# In Powershell Prompt : conda install -c conda-forge multitasking
# pip install -i https://pypi.anaconda.org/ranaroussi/simple yfinance

import yfinance as yf

# To show all your output File -> Preferences -> Settings Search for Notebook
# Notebook Output Text Line Limit and set to 100

# Used for file handling like deleting files
import os

# conda install -c conda-forge cufflinks-py
# conda install -c plotly plotly
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

from plotly.subplots import make_subplots

# New Imports
# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## Constants - Fill in your details!

# %%
# Provide a valid directory path - in here all the financial CSV data will be saved.
PATH = "C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/"

# Start end date defaults
S_DATE = "2018-02-01"
E_DATE = "2023-12-06"
S_DATE_DT = pd.to_datetime(S_DATE)
E_DATE_DT = pd.to_datetime(E_DATE)

# %% [markdown]
# ## Get Column Data from CSV

# %%
def get_column_from_csv(file, col_name):
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df[col_name]

# %% [markdown]
# ## Get Stock Tickers

# %%
tickers = get_column_from_csv("C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/nasdaq_screener.csv", "Symbol")
print(len(tickers))
# Out:
# 8109

# %% [markdown]
# ## Save Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(folder, ticker):
    stock = yf.Ticker(ticker)
    
    try:
        print("Get Data for : ", ticker)
        # Get historical closing price data
        df = stock.history(period="5y")
    
        # Wait 2 seconds
        # time.sleep(2)
        
        # Remove the period for saving the file name
        # Save data to a CSV file
        # File to save to 
        the_file = folder + ticker.replace(".", "_") + '.csv'
        print(the_file, " Saved")
        df.to_csv(the_file)
    except Exception as ex:
        print("Couldn't Get Data for :", ticker)

# %% [markdown]
# ## Download All Stocks

# %%
for x in range(0, len(tickers)):
    save_to_csv_from_yahoo(DIRECTORY, tickers[x])
    print("Finished")
# Out:
# - NXDT^A: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXDT^A.csv  Saved
# Finished
# Get Data for :  NXE
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXE.csv  Saved
# Finished
# Get Data for :  NXG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXG.csv  Saved
# Finished
# Get Data for :  NXGL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXGL.csv  Saved
# Finished
# Get Data for :  NXGLW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXGLW.csv  Saved
# Finished
# Get Data for :  NXGN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXGN.csv  Saved
# Finished
# Get Data for :  NXJ
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXJ.csv  Saved
# Finished
# Get Data for :  NXL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXL.csv  Saved
# Finished
# Get Data for :  NXLIW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXLIW.csv  Saved
# Finished
# Get Data for :  NXN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXN.csv  Saved
# Finished
# Get Data for :  NXP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXP.csv  Saved
# Finished
# Get Data for :  NXPI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXPI.csv  Saved
# Finished
# Get Data for :  NXPL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXPL.csv  Saved
# Finished
# Get Data for :  NXPLW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXPLW.csv  Saved
# Finished
# Get Data for :  NXRT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXRT.csv  Saved
# Finished
# Get Data for :  NXST
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXST.csv  Saved
# Finished
# Get Data for :  NXTC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXTC.csv  Saved
# Finished
# Get Data for :  NXTP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NXTP.csv  Saved
# Finished
# Get Data for :  NYAX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NYAX.csv  Saved
# Finished
# Get Data for :  NYC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NYC.csv  Saved
# Finished
# Get Data for :  NYCB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NYCB.csv  Saved
# Finished
# Get Data for :  NYCB^A
# - NYCB^A: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NYCB^A.csv  Saved
# Finished
# Get Data for :  NYCB^U
# - NYCB^U: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NYCB^U.csv  Saved
# Finished
# Get Data for :  NYMT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NYMT.csv  Saved
# Finished
# Get Data for :  NYMTL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NYMTL.csv  Saved
# Finished
# Get Data for :  NYMTM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NYMTM.csv  Saved
# Finished
# Get Data for :  NYMTN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NYMTN.csv  Saved
# Finished
# Get Data for :  NYMTZ
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NYMTZ.csv  Saved
# Finished
# Get Data for :  NYMX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NYMX.csv  Saved
# Finished
# Get Data for :  NYT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NYT.csv  Saved
# Finished
# Get Data for :  NYXH
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NYXH.csv  Saved
# Finished
# Get Data for :  NZF
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/NZF.csv  Saved
# Finished
# Get Data for :  O
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/O.csv  Saved
# Finished
# Get Data for :  OABI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OABI.csv  Saved
# Finished
# Get Data for :  OABIW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OABIW.csv  Saved
# Finished
# Get Data for :  OAK^A
# - OAK^A: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OAK^A.csv  Saved
# Finished
# Get Data for :  OAK^B
# - OAK^B: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OAK^B.csv  Saved
# Finished
# Get Data for :  OB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OB.csv  Saved
# Finished
# Get Data for :  OBE
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OBE.csv  Saved
# Finished
# Get Data for :  OBLG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OBLG.csv  Saved
# Finished
# Get Data for :  OBNK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OBNK.csv  Saved
# Finished
# Get Data for :  OBSV
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OBSV.csv  Saved
# Finished
# Get Data for :  OBT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OBT.csv  Saved
# Finished
# Get Data for :  OC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OC.csv  Saved
# Finished
# Get Data for :  OCAX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCAX.csv  Saved
# Finished
# Get Data for :  OCAXU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCAXU.csv  Saved
# Finished
# Get Data for :  OCAXW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCAXW.csv  Saved
# Finished
# Get Data for :  OCC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCC.csv  Saved
# Finished
# Get Data for :  OCCI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCCI.csv  Saved
# Finished
# Get Data for :  OCCIN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCCIN.csv  Saved
# Finished
# Get Data for :  OCCIO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCCIO.csv  Saved
# Finished
# Get Data for :  OCFC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCFC.csv  Saved
# Finished
# Get Data for :  OCFCP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCFCP.csv  Saved
# Finished
# Get Data for :  OCFT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCFT.csv  Saved
# Finished
# Get Data for :  OCG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCG.csv  Saved
# Finished
# Get Data for :  OCGN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCGN.csv  Saved
# Finished
# Get Data for :  OCN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCN.csv  Saved
# Finished
# Get Data for :  OCSL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCSL.csv  Saved
# Finished
# Get Data for :  OCUL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCUL.csv  Saved
# Finished
# Get Data for :  OCUP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCUP.csv  Saved
# Finished
# Get Data for :  OCX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OCX.csv  Saved
# Finished
# Get Data for :  ODC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ODC.csv  Saved
# Finished
# Get Data for :  ODFL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ODFL.csv  Saved
# Finished
# Get Data for :  ODP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ODP.csv  Saved
# Finished
# Get Data for :  ODV
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ODV.csv  Saved
# Finished
# Get Data for :  OEC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OEC.csv  Saved
# Finished
# Get Data for :  OESX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OESX.csv  Saved
# Finished
# Get Data for :  OFC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OFC.csv  Saved
# Finished
# Get Data for :  OFED
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OFED.csv  Saved
# Finished
# Get Data for :  OFG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OFG.csv  Saved
# Finished
# Get Data for :  OFIX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OFIX.csv  Saved
# Finished
# Get Data for :  OFLX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OFLX.csv  Saved
# Finished
# Get Data for :  OFS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OFS.csv  Saved
# Finished
# Get Data for :  OFSSH
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OFSSH.csv  Saved
# Finished
# Get Data for :  OG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OG.csv  Saved
# Finished
# Get Data for :  OGE
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OGE.csv  Saved
# Finished
# Get Data for :  OGEN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OGEN.csv  Saved
# Finished
# Get Data for :  OGI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OGI.csv  Saved
# Finished
# Get Data for :  OGN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OGN.csv  Saved
# Finished
# Get Data for :  OGS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OGS.csv  Saved
# Finished
# Get Data for :  OHAA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OHAA.csv  Saved
# Finished
# Get Data for :  OHAAW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OHAAW.csv  Saved
# Finished
# Get Data for :  OHI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OHI.csv  Saved
# Finished
# Get Data for :  OI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OI.csv  Saved
# Finished
# Get Data for :  OIA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OIA.csv  Saved
# Finished
# Get Data for :  OIG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OIG.csv  Saved
# Finished
# Get Data for :  OII
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OII.csv  Saved
# Finished
# Get Data for :  OIIM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OIIM.csv  Saved
# Finished
# Get Data for :  OIS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OIS.csv  Saved
# Finished
# Get Data for :  OKE
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OKE.csv  Saved
# Finished
# Get Data for :  OKTA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OKTA.csv  Saved
# Finished
# Get Data for :  OKYO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OKYO.csv  Saved
# Finished
# Get Data for :  OLB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OLB.csv  Saved
# Finished
# Get Data for :  OLED
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OLED.csv  Saved
# Finished
# Get Data for :  OLIT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OLIT.csv  Saved
# Finished
# Get Data for :  OLK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OLK.csv  Saved
# Finished
# Get Data for :  OLLI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OLLI.csv  Saved
# Finished
# Get Data for :  OLMA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OLMA.csv  Saved
# Finished
# Get Data for :  OLN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OLN.csv  Saved
# Finished
# Get Data for :  OLO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OLO.csv  Saved
# Finished
# Get Data for :  OLP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OLP.csv  Saved
# Finished
# Get Data for :  OLPX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OLPX.csv  Saved
# Finished
# Get Data for :  OM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OM.csv  Saved
# Finished
# Get Data for :  OMAB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OMAB.csv  Saved
# Finished
# Get Data for :  OMC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OMC.csv  Saved
# Finished
# Get Data for :  OMCL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OMCL.csv  Saved
# Finished
# Get Data for :  OMEG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OMEG.csv  Saved
# Finished
# Get Data for :  OMER
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OMER.csv  Saved
# Finished
# Get Data for :  OMEX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OMEX.csv  Saved
# Finished
# Get Data for :  OMF
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OMF.csv  Saved
# Finished
# Get Data for :  OMGA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OMGA.csv  Saved
# Finished
# Get Data for :  OMI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OMI.csv  Saved
# Finished
# Get Data for :  OMIC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OMIC.csv  Saved
# Finished
# Get Data for :  OMQS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OMQS.csv  Saved
# Finished
# Get Data for :  ON
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ON.csv  Saved
# Finished
# Get Data for :  ONB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONB.csv  Saved
# Finished
# Get Data for :  ONBPO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONBPO.csv  Saved
# Finished
# Get Data for :  ONBPP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONBPP.csv  Saved
# Finished
# Get Data for :  ONCR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONCR.csv  Saved
# Finished
# Get Data for :  ONCS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONCS.csv  Saved
# Finished
# Get Data for :  ONCT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONCT.csv  Saved
# Finished
# Get Data for :  ONCY
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONCY.csv  Saved
# Finished
# Get Data for :  ONDS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONDS.csv  Saved
# Finished
# Get Data for :  ONEM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONEM.csv  Saved
# Finished
# Get Data for :  ONEW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONEW.csv  Saved
# Finished
# Get Data for :  ONFO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONFO.csv  Saved
# Finished
# Get Data for :  ONFOW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONFOW.csv  Saved
# Finished
# Get Data for :  ONL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONL.csv  Saved
# Finished
# Get Data for :  ONON
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONON.csv  Saved
# Finished
# Get Data for :  ONTF
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONTF.csv  Saved
# Finished
# Get Data for :  ONTO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONTO.csv  Saved
# Finished
# Get Data for :  ONTX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONTX.csv  Saved
# Finished
# Get Data for :  ONVO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONVO.csv  Saved
# Finished
# Get Data for :  ONYX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONYX.csv  Saved
# Finished
# Get Data for :  ONYXU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONYXU.csv  Saved
# Finished
# Get Data for :  ONYXW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ONYXW.csv  Saved
# Finished
# Get Data for :  OOMA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OOMA.csv  Saved
# Finished
# Get Data for :  OP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OP.csv  Saved
# Finished
# Get Data for :  OPA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPA.csv  Saved
# Finished
# Get Data for :  OPAD
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPAD.csv  Saved
# Finished
# Get Data for :  OPAL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPAL.csv  Saved
# Finished
# Get Data for :  OPALW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPALW.csv  Saved
# Finished
# Get Data for :  OPBK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPBK.csv  Saved
# Finished
# Get Data for :  OPCH
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPCH.csv  Saved
# Finished
# Get Data for :  OPEN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPEN.csv  Saved
# Finished
# Get Data for :  OPFI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPFI.csv  Saved
# Finished
# Get Data for :  OPGN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPGN.csv  Saved
# Finished
# Get Data for :  OPHC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPHC.csv  Saved
# Finished
# Get Data for :  OPI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPI.csv  Saved
# Finished
# Get Data for :  OPINL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPINL.csv  Saved
# Finished
# Get Data for :  OPK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPK.csv  Saved
# Finished
# Get Data for :  OPNT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPNT.csv  Saved
# Finished
# Get Data for :  OPOF
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPOF.csv  Saved
# Finished
# Get Data for :  OPP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPP.csv  Saved
# Finished
# Get Data for :  OPP^A
# - OPP^A: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPP^A.csv  Saved
# Finished
# Get Data for :  OPP^B
# - OPP^B: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPP^B.csv  Saved
# Finished
# Get Data for :  OPRA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPRA.csv  Saved
# Finished
# Get Data for :  OPRT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPRT.csv  Saved
# Finished
# Get Data for :  OPRX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPRX.csv  Saved
# Finished
# Get Data for :  OPT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPT.csv  Saved
# Finished
# Get Data for :  OPTN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPTN.csv  Saved
# Finished
# Get Data for :  OPTT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPTT.csv  Saved
# Finished
# Get Data for :  OPY
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OPY.csv  Saved
# Finished
# Get Data for :  OR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OR.csv  Saved
# Finished
# Get Data for :  ORA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORA.csv  Saved
# Finished
# Get Data for :  ORAN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORAN.csv  Saved
# Finished
# Get Data for :  ORC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORC.csv  Saved
# Finished
# Get Data for :  ORCC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORCC.csv  Saved
# Finished
# Get Data for :  ORCL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORCL.csv  Saved
# Finished
# Get Data for :  ORGN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORGN.csv  Saved
# Finished
# Get Data for :  ORGNW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORGNW.csv  Saved
# Finished
# Get Data for :  ORGO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORGO.csv  Saved
# Finished
# Get Data for :  ORGS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORGS.csv  Saved
# Finished
# Get Data for :  ORI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORI.csv  Saved
# Finished
# Get Data for :  ORIA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORIA.csv  Saved
# Finished
# Get Data for :  ORIAW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORIAW.csv  Saved
# Finished
# Get Data for :  ORIC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORIC.csv  Saved
# Finished
# Get Data for :  ORLA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORLA.csv  Saved
# Finished
# Get Data for :  ORLY
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORLY.csv  Saved
# Finished
# Get Data for :  ORMP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORMP.csv  Saved
# Finished
# Get Data for :  ORN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORN.csv  Saved
# Finished
# Get Data for :  ORRF
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORRF.csv  Saved
# Finished
# Get Data for :  ORTX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ORTX.csv  Saved
# Finished
# Get Data for :  OSA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSA.csv  Saved
# Finished
# Get Data for :  OSAAW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSAAW.csv  Saved
# Finished
# Get Data for :  OSBC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSBC.csv  Saved
# Finished
# Get Data for :  OSCR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSCR.csv  Saved
# Finished
# Get Data for :  OSG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSG.csv  Saved
# Finished
# Get Data for :  OSH
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSH.csv  Saved
# Finished
# Get Data for :  OSI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSI.csv  Saved
# Finished
# Get Data for :  OSIS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSIS.csv  Saved
# Finished
# Get Data for :  OSK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSK.csv  Saved
# Finished
# Get Data for :  OSPN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSPN.csv  Saved
# Finished
# Get Data for :  OSS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSS.csv  Saved
# Finished
# Get Data for :  OST
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OST.csv  Saved
# Finished
# Get Data for :  OSTK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSTK.csv  Saved
# Finished
# Get Data for :  OSTR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSTR.csv  Saved
# Finished
# Get Data for :  OSTRU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSTRU.csv  Saved
# Finished
# Get Data for :  OSTRW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSTRW.csv  Saved
# Finished
# Get Data for :  OSUR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSUR.csv  Saved
# Finished
# Get Data for :  OSW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OSW.csv  Saved
# Finished
# Get Data for :  OTEC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OTEC.csv  Saved
# Finished
# Get Data for :  OTECU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OTECU.csv  Saved
# Finished
# Get Data for :  OTECW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OTECW.csv  Saved
# Finished
# Get Data for :  OTEX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OTEX.csv  Saved
# Finished
# Get Data for :  OTIC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OTIC.csv  Saved
# Finished
# Get Data for :  OTIS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OTIS.csv  Saved
# Finished
# Get Data for :  OTLK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OTLK.csv  Saved
# Finished
# Get Data for :  OTLY
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OTLY.csv  Saved
# Finished
# Get Data for :  OTMO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OTMO.csv  Saved
# Finished
# Get Data for :  OTMOW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OTMOW.csv  Saved
# Finished
# Get Data for :  OTRK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OTRK.csv  Saved
# Finished
# Get Data for :  OTRKP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OTRKP.csv  Saved
# Finished
# Get Data for :  OTTR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OTTR.csv  Saved
# Finished
# Get Data for :  OUST
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OUST.csv  Saved
# Finished
# Get Data for :  OUT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OUT.csv  Saved
# Finished
# Get Data for :  OVBC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OVBC.csv  Saved
# Finished
# Get Data for :  OVID
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OVID.csv  Saved
# Finished
# Get Data for :  OVLY
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OVLY.csv  Saved
# Finished
# Get Data for :  OVV
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OVV.csv  Saved
# Finished
# Get Data for :  OWL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OWL.csv  Saved
# Finished
# Get Data for :  OWLT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OWLT.csv  Saved
# Finished
# Get Data for :  OXAC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXAC.csv  Saved
# Finished
# Get Data for :  OXACW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXACW.csv  Saved
# Finished
# Get Data for :  OXBR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXBR.csv  Saved
# Finished
# Get Data for :  OXLC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXLC.csv  Saved
# Finished
# Get Data for :  OXLCL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXLCL.csv  Saved
# Finished
# Get Data for :  OXLCM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXLCM.csv  Saved
# Finished
# Get Data for :  OXLCN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXLCN.csv  Saved
# Finished
# Get Data for :  OXLCO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXLCO.csv  Saved
# Finished
# Get Data for :  OXLCP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXLCP.csv  Saved
# Finished
# Get Data for :  OXLCZ
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXLCZ.csv  Saved
# Finished
# Get Data for :  OXM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXM.csv  Saved
# Finished
# Get Data for :  OXSQ
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXSQ.csv  Saved
# Finished
# Get Data for :  OXSQG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXSQG.csv  Saved
# Finished
# Get Data for :  OXSQL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXSQL.csv  Saved
# Finished
# Get Data for :  OXSQZ
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXSQZ.csv  Saved
# Finished
# Get Data for :  OXUS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXUS.csv  Saved
# Finished
# Get Data for :  OXUSU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXUSU.csv  Saved
# Finished
# Get Data for :  OXUSW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXUSW.csv  Saved
# Finished
# Get Data for :  OXY
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OXY.csv  Saved
# Finished
# Get Data for :  OYST
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OYST.csv  Saved
# Finished
# Get Data for :  OZ
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OZ.csv  Saved
# Finished
# Get Data for :  OZK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OZK.csv  Saved
# Finished
# Get Data for :  OZKAP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/OZKAP.csv  Saved
# Finished
# Get Data for :  PAA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAA.csv  Saved
# Finished
# Get Data for :  PAAS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAAS.csv  Saved
# Finished
# Get Data for :  PAC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAC.csv  Saved
# Finished
# Get Data for :  PACB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PACB.csv  Saved
# Finished
# Get Data for :  PACI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PACI.csv  Saved
# Finished
# Get Data for :  PACK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PACK.csv  Saved
# Finished
# Get Data for :  PACW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PACW.csv  Saved
# Finished
# Get Data for :  PACWP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PACWP.csv  Saved
# Finished
# Get Data for :  PACX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PACX.csv  Saved
# Finished
# Get Data for :  PACXU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PACXU.csv  Saved
# Finished
# Get Data for :  PACXW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PACXW.csv  Saved
# Finished
# Get Data for :  PAFO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAFO.csv  Saved
# Finished
# Get Data for :  PAFOR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAFOR.csv  Saved
# Finished
# Get Data for :  PAFOU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAFOU.csv  Saved
# Finished
# Get Data for :  PAG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAG.csv  Saved
# Finished
# Get Data for :  PAGP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAGP.csv  Saved
# Finished
# Get Data for :  PAGS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAGS.csv  Saved
# Finished
# Get Data for :  PAHC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAHC.csv  Saved
# Finished
# Get Data for :  PAI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAI.csv  Saved
# Finished
# Get Data for :  PALI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PALI.csv  Saved
# Finished
# Get Data for :  PALT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PALT.csv  Saved
# Finished
# Get Data for :  PAM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAM.csv  Saved
# Finished
# Get Data for :  PANA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PANA.csv  Saved
# Finished
# Get Data for :  PANL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PANL.csv  Saved
# Finished
# Get Data for :  PANW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PANW.csv  Saved
# Finished
# Get Data for :  PAR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAR.csv  Saved
# Finished
# Get Data for :  PARA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PARA.csv  Saved
# Finished
# Get Data for :  PARAA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PARAA.csv  Saved
# Finished
# Get Data for :  PARAP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PARAP.csv  Saved
# Finished
# Get Data for :  PARR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PARR.csv  Saved
# Finished
# Get Data for :  PASG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PASG.csv  Saved
# Finished
# Get Data for :  PATH
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PATH.csv  Saved
# Finished
# Get Data for :  PATI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PATI.csv  Saved
# Finished
# Get Data for :  PATK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PATK.csv  Saved
# Finished
# Get Data for :  PAVM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAVM.csv  Saved
# Finished
# Get Data for :  PAVMZ
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAVMZ.csv  Saved
# Finished
# Get Data for :  PAX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAX.csv  Saved
# Finished
# Get Data for :  PAXS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAXS.csv  Saved
# Finished
# Get Data for :  PAY
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAY.csv  Saved
# Finished
# Get Data for :  PAYA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAYA.csv  Saved
# Finished
# Get Data for :  PAYC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAYC.csv  Saved
# Finished
# Get Data for :  PAYO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAYO.csv  Saved
# Finished
# Get Data for :  PAYOW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAYOW.csv  Saved
# Finished
# Get Data for :  PAYS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAYS.csv  Saved
# Finished
# Get Data for :  PAYX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PAYX.csv  Saved
# Finished
# Get Data for :  PB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PB.csv  Saved
# Finished
# Get Data for :  PBA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBA.csv  Saved
# Finished
# Get Data for :  PBAX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBAX.csv  Saved
# Finished
# Get Data for :  PBAXW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBAXW.csv  Saved
# Finished
# Get Data for :  PBBK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBBK.csv  Saved
# Finished
# Get Data for :  PBF
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBF.csv  Saved
# Finished
# Get Data for :  PBFS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBFS.csv  Saved
# Finished
# Get Data for :  PBH
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBH.csv  Saved
# Finished
# Get Data for :  PBHC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBHC.csv  Saved
# Finished
# Get Data for :  PBI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBI.csv  Saved
# Finished
# Get Data for :  PBI^B
# - PBI^B: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBI^B.csv  Saved
# Finished
# Get Data for :  PBLA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBLA.csv  Saved
# Finished
# Get Data for :  PBPB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBPB.csv  Saved
# Finished
# Get Data for :  PBR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBR.csv  Saved
# Finished
# Get Data for :  PBT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBT.csv  Saved
# Finished
# Get Data for :  PBTS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBTS.csv  Saved
# Finished
# Get Data for :  PBYI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PBYI.csv  Saved
# Finished
# Get Data for :  PCAR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCAR.csv  Saved
# Finished
# Get Data for :  PCB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCB.csv  Saved
# Finished
# Get Data for :  PCCT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCCT.csv  Saved
# Finished
# Get Data for :  PCCTU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCCTU.csv  Saved
# Finished
# Get Data for :  PCCTW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCCTW.csv  Saved
# Finished
# Get Data for :  PCF
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCF.csv  Saved
# Finished
# Get Data for :  PCG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCG.csv  Saved
# Finished
# Get Data for :  PCG^A
# - PCG^A: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCG^A.csv  Saved
# Finished
# Get Data for :  PCG^B
# - PCG^B: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCG^B.csv  Saved
# Finished
# Get Data for :  PCG^C
# - PCG^C: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCG^C.csv  Saved
# Finished
# Get Data for :  PCG^D
# - PCG^D: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCG^D.csv  Saved
# Finished
# Get Data for :  PCG^E
# - PCG^E: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCG^E.csv  Saved
# Finished
# Get Data for :  PCG^G
# - PCG^G: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCG^G.csv  Saved
# Finished
# Get Data for :  PCG^H
# - PCG^H: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCG^H.csv  Saved
# Finished
# Get Data for :  PCG^I
# - PCG^I: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCG^I.csv  Saved
# Finished
# Get Data for :  PCGU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCGU.csv  Saved
# Finished
# Get Data for :  PCH
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCH.csv  Saved
# Finished
# Get Data for :  PCK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCK.csv  Saved
# Finished
# Get Data for :  PCM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCM.csv  Saved
# Finished
# Get Data for :  PCN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCN.csv  Saved
# Finished
# Get Data for :  PCOR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCOR.csv  Saved
# Finished
# Get Data for :  PCQ
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCQ.csv  Saved
# Finished
# Get Data for :  PCRX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCRX.csv  Saved
# Finished
# Get Data for :  PCSA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCSA.csv  Saved
# Finished
# Get Data for :  PCSB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCSB.csv  Saved
# Finished
# Get Data for :  PCT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCT.csv  Saved
# Finished
# Get Data for :  PCTI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCTI.csv  Saved
# Finished
# Get Data for :  PCTTU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCTTU.csv  Saved
# Finished
# Get Data for :  PCTTW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCTTW.csv  Saved
# Finished
# Get Data for :  PCTY
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCTY.csv  Saved
# Finished
# Get Data for :  PCVX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCVX.csv  Saved
# Finished
# Get Data for :  PCX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCX.csv  Saved
# Finished
# Get Data for :  PCXCW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCXCW.csv  Saved
# Finished
# Get Data for :  PCYG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCYG.csv  Saved
# Finished
# Get Data for :  PCYO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PCYO.csv  Saved
# Finished
# Get Data for :  PD
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PD.csv  Saved
# Finished
# Get Data for :  PDCE
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PDCE.csv  Saved
# Finished
# Get Data for :  PDCO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PDCO.csv  Saved
# Finished
# Get Data for :  PDD
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PDD.csv  Saved
# Finished
# Get Data for :  PDEX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PDEX.csv  Saved
# Finished
# Get Data for :  PDFS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PDFS.csv  Saved
# Finished
# Get Data for :  PDI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PDI.csv  Saved
# Finished
# Get Data for :  PDLB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PDLB.csv  Saved
# Finished
# Get Data for :  PDM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PDM.csv  Saved
# Finished
# Get Data for :  PDO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PDO.csv  Saved
# Finished
# Get Data for :  PDOT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PDOT.csv  Saved
# Finished
# Get Data for :  PDS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PDS.csv  Saved
# Finished
# Get Data for :  PDSB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PDSB.csv  Saved
# Finished
# Get Data for :  PDT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PDT.csv  Saved
# Finished
# Get Data for :  PEAK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEAK.csv  Saved
# Finished
# Get Data for :  PEAR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEAR.csv  Saved
# Finished
# Get Data for :  PEARW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEARW.csv  Saved
# Finished
# Get Data for :  PEB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEB.csv  Saved
# Finished
# Get Data for :  PEB^E
# - PEB^E: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEB^E.csv  Saved
# Finished
# Get Data for :  PEB^F
# - PEB^F: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEB^F.csv  Saved
# Finished
# Get Data for :  PEB^G
# - PEB^G: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEB^G.csv  Saved
# Finished
# Get Data for :  PEB^H
# - PEB^H: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEB^H.csv  Saved
# Finished
# Get Data for :  PEBK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEBK.csv  Saved
# Finished
# Get Data for :  PEBO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEBO.csv  Saved
# Finished
# Get Data for :  PECO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PECO.csv  Saved
# Finished
# Get Data for :  PED
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PED.csv  Saved
# Finished
# Get Data for :  PEG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEG.csv  Saved
# Finished
# Get Data for :  PEGA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEGA.csv  Saved
# Finished
# Get Data for :  PEGR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEGR.csv  Saved
# Finished
# Get Data for :  PEGRU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEGRU.csv  Saved
# Finished
# Get Data for :  PEGRW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEGRW.csv  Saved
# Finished
# Get Data for :  PEGY
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEGY.csv  Saved
# Finished
# Get Data for :  PEN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEN.csv  Saved
# Finished
# Get Data for :  PENN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PENN.csv  Saved
# Finished
# Get Data for :  PEO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEO.csv  Saved
# Finished
# Get Data for :  PEP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEP.csv  Saved
# Finished
# Get Data for :  PEPG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEPG.csv  Saved
# Finished
# Get Data for :  PEPL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEPL.csv  Saved
# Finished
# Get Data for :  PEPLU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEPLU.csv  Saved
# Finished
# Get Data for :  PEPLW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEPLW.csv  Saved
# Finished
# Get Data for :  PERF
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PERF.csv  Saved
# Finished
# Get Data for :  PERI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PERI.csv  Saved
# Finished
# Get Data for :  PESI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PESI.csv  Saved
# Finished
# Get Data for :  PET
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PET.csv  Saved
# Finished
# Get Data for :  PETQ
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PETQ.csv  Saved
# Finished
# Get Data for :  PETS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PETS.csv  Saved
# Finished
# Get Data for :  PETV
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PETV.csv  Saved
# Finished
# Get Data for :  PETVW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PETVW.csv  Saved
# Finished
# Get Data for :  PETWW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PETWW.csv  Saved
# Finished
# Get Data for :  PETZ
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PETZ.csv  Saved
# Finished
# Get Data for :  PEV
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PEV.csv  Saved
# Finished
# Get Data for :  PFBC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFBC.csv  Saved
# Finished
# Get Data for :  PFC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFC.csv  Saved
# Finished
# Get Data for :  PFD
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFD.csv  Saved
# Finished
# Get Data for :  PFDR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFDR.csv  Saved
# Finished
# Get Data for :  PFDRW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFDRW.csv  Saved
# Finished
# Get Data for :  PFE
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFE.csv  Saved
# Finished
# Get Data for :  PFG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFG.csv  Saved
# Finished
# Get Data for :  PFGC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFGC.csv  Saved
# Finished
# Get Data for :  PFH
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFH.csv  Saved
# Finished
# Get Data for :  PFHD
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFHD.csv  Saved
# Finished
# Get Data for :  PFIE
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFIE.csv  Saved
# Finished
# Get Data for :  PFIN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFIN.csv  Saved
# Finished
# Get Data for :  PFIS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFIS.csv  Saved
# Finished
# Get Data for :  PFL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFL.csv  Saved
# Finished
# Get Data for :  PFLT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFLT.csv  Saved
# Finished
# Get Data for :  PFMT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFMT.csv  Saved
# Finished
# Get Data for :  PFN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFN.csv  Saved
# Finished
# Get Data for :  PFO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFO.csv  Saved
# Finished
# Get Data for :  PFS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFS.csv  Saved
# Finished
# Get Data for :  PFSI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFSI.csv  Saved
# Finished
# Get Data for :  PFSW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFSW.csv  Saved
# Finished
# Get Data for :  PFTA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFTA.csv  Saved
# Finished
# Get Data for :  PFTAU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFTAU.csv  Saved
# Finished
# Get Data for :  PFTAW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/PFTAW.csv  Saved
# Finished
# Get Data for :  PFX
# ...
# Finished
# Get Data for :  WWW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/WWW.csv  Saved
# Finished
# Get Data for :  WY
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/WY.csv  Saved
# Finished
# Get Data for :  WYNN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/WYNN.csv  Saved
# Finished
# Get Data for :  WYY
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/WYY.csv  Saved
# Finished
# Get Data for :  X
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/X.csv  Saved
# Finished
# Get Data for :  XAIR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XAIR.csv  Saved
# Finished
# Get Data for :  XBIO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XBIO.csv  Saved
# Finished
# Get Data for :  XBIOW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XBIOW.csv  Saved
# Finished
# Get Data for :  XBIT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XBIT.csv  Saved
# Finished
# Get Data for :  XCUR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XCUR.csv  Saved
# Finished
# Get Data for :  XEL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XEL.csv  Saved
# Finished
# Get Data for :  XELA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XELA.csv  Saved
# Finished
# Get Data for :  XELAP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XELAP.csv  Saved
# Finished
# Get Data for :  XELB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XELB.csv  Saved
# Finished
# Get Data for :  XENE
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XENE.csv  Saved
# Finished
# Get Data for :  XERS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XERS.csv  Saved
# Finished
# Get Data for :  XFIN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XFIN.csv  Saved
# Finished
# Get Data for :  XFINU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XFINU.csv  Saved
# Finished
# Get Data for :  XFINW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XFINW.csv  Saved
# Finished
# Get Data for :  XFLT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XFLT.csv  Saved
# Finished
# Get Data for :  XFLT^A
# - XFLT^A: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XFLT^A.csv  Saved
# Finished
# Get Data for :  XFOR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XFOR.csv  Saved
# Finished
# Get Data for :  XGN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XGN.csv  Saved
# Finished
# Get Data for :  XHR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XHR.csv  Saved
# Finished
# Get Data for :  XIN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XIN.csv  Saved
# Finished
# Get Data for :  XLO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XLO.csv  Saved
# Finished
# Get Data for :  XM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XM.csv  Saved
# Finished
# Get Data for :  XMTR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XMTR.csv  Saved
# Finished
# Get Data for :  XNCR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XNCR.csv  Saved
# Finished
# Get Data for :  XNET
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XNET.csv  Saved
# Finished
# Get Data for :  XOM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XOM.csv  Saved
# Finished
# Get Data for :  XOMA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XOMA.csv  Saved
# Finished
# Get Data for :  XOMAO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XOMAO.csv  Saved
# Finished
# Get Data for :  XOMAP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XOMAP.csv  Saved
# Finished
# Get Data for :  XOS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XOS.csv  Saved
# Finished
# Get Data for :  XOSWW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XOSWW.csv  Saved
# Finished
# Get Data for :  XP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XP.csv  Saved
# Finished
# Get Data for :  XPAX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XPAX.csv  Saved
# Finished
# Get Data for :  XPAXW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XPAXW.csv  Saved
# Finished
# Get Data for :  XPDB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XPDB.csv  Saved
# Finished
# Get Data for :  XPDBU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XPDBU.csv  Saved
# Finished
# Get Data for :  XPDBW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XPDBW.csv  Saved
# Finished
# Get Data for :  XPEL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XPEL.csv  Saved
# Finished
# Get Data for :  XPER
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XPER.csv  Saved
# Finished
# Get Data for :  XPEV
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XPEV.csv  Saved
# Finished
# Get Data for :  XPL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XPL.csv  Saved
# Finished
# Get Data for :  XPO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XPO.csv  Saved
# Finished
# Get Data for :  XPOF
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XPOF.csv  Saved
# Finished
# Get Data for :  XPON
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XPON.csv  Saved
# Finished
# Get Data for :  XPRO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XPRO.csv  Saved
# Finished
# Get Data for :  XRAY
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XRAY.csv  Saved
# Finished
# Get Data for :  XRTX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XRTX.csv  Saved
# Finished
# Get Data for :  XRX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XRX.csv  Saved
# Finished
# Get Data for :  XTLB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XTLB.csv  Saved
# Finished
# Get Data for :  XTNT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XTNT.csv  Saved
# Finished
# Get Data for :  XWEL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XWEL.csv  Saved
# Finished
# Get Data for :  XXII
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XXII.csv  Saved
# Finished
# Get Data for :  XYF
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XYF.csv  Saved
# Finished
# Get Data for :  XYL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/XYL.csv  Saved
# Finished
# Get Data for :  YALA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YALA.csv  Saved
# Finished
# Get Data for :  YCBD
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YCBD.csv  Saved
# Finished
# Get Data for :  YCBD^A
# - YCBD^A: No data found, symbol may be delisted
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YCBD^A.csv  Saved
# Finished
# Get Data for :  YELL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YELL.csv  Saved
# Finished
# Get Data for :  YELP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YELP.csv  Saved
# Finished
# Get Data for :  YETI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YETI.csv  Saved
# Finished
# Get Data for :  YEXT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YEXT.csv  Saved
# Finished
# Get Data for :  YGMZ
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YGMZ.csv  Saved
# Finished
# Get Data for :  YI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YI.csv  Saved
# Finished
# Get Data for :  YJ
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YJ.csv  Saved
# Finished
# Get Data for :  YMAB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YMAB.csv  Saved
# Finished
# Get Data for :  YMM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YMM.csv  Saved
# Finished
# Get Data for :  YMTX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YMTX.csv  Saved
# Finished
# Get Data for :  YORW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YORW.csv  Saved
# Finished
# Get Data for :  YOSH
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YOSH.csv  Saved
# Finished
# Get Data for :  YOTA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YOTA.csv  Saved
# Finished
# Get Data for :  YOTAR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YOTAR.csv  Saved
# Finished
# Get Data for :  YOTAU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YOTAU.csv  Saved
# Finished
# Get Data for :  YOTAW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YOTAW.csv  Saved
# Finished
# Get Data for :  YOU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YOU.csv  Saved
# Finished
# Get Data for :  YPF
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YPF.csv  Saved
# Finished
# Get Data for :  YQ
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YQ.csv  Saved
# Finished
# Get Data for :  YRD
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YRD.csv  Saved
# Finished
# Get Data for :  YSG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YSG.csv  Saved
# Finished
# Get Data for :  YTEN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YTEN.csv  Saved
# Finished
# Get Data for :  YTPG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YTPG.csv  Saved
# Finished
# Get Data for :  YTRA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YTRA.csv  Saved
# Finished
# Get Data for :  YUM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YUM.csv  Saved
# Finished
# Get Data for :  YUMC
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YUMC.csv  Saved
# Finished
# Get Data for :  YVR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YVR.csv  Saved
# Finished
# Get Data for :  YY
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/YY.csv  Saved
# Finished
# Get Data for :  Z
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/Z.csv  Saved
# Finished
# Get Data for :  ZBH
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZBH.csv  Saved
# Finished
# Get Data for :  ZBRA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZBRA.csv  Saved
# Finished
# Get Data for :  ZCMD
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZCMD.csv  Saved
# Finished
# Get Data for :  ZD
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZD.csv  Saved
# Finished
# Get Data for :  ZDGE
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZDGE.csv  Saved
# Finished
# Get Data for :  ZENV
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZENV.csv  Saved
# Finished
# Get Data for :  ZEPP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZEPP.csv  Saved
# Finished
# Get Data for :  ZEST
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZEST.csv  Saved
# Finished
# Get Data for :  ZETA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZETA.csv  Saved
# Finished
# Get Data for :  ZEUS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZEUS.csv  Saved
# Finished
# Get Data for :  ZEV
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZEV.csv  Saved
# Finished
# Get Data for :  ZFOX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZFOX.csv  Saved
# Finished
# Get Data for :  ZFOXW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZFOXW.csv  Saved
# Finished
# Get Data for :  ZG
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZG.csv  Saved
# Finished
# Get Data for :  ZGN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZGN.csv  Saved
# Finished
# Get Data for :  ZH
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZH.csv  Saved
# Finished
# Get Data for :  ZI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZI.csv  Saved
# Finished
# Get Data for :  ZIM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZIM.csv  Saved
# Finished
# Get Data for :  ZIMV
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZIMV.csv  Saved
# Finished
# Get Data for :  ZING
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZING.csv  Saved
# Finished
# Get Data for :  ZION
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZION.csv  Saved
# Finished
# Get Data for :  ZIONL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZIONL.csv  Saved
# Finished
# Get Data for :  ZIONO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZIONO.csv  Saved
# Finished
# Get Data for :  ZIONP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZIONP.csv  Saved
# Finished
# Get Data for :  ZIP
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZIP.csv  Saved
# Finished
# Get Data for :  ZIVO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZIVO.csv  Saved
# Finished
# Get Data for :  ZIVOW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZIVOW.csv  Saved
# Finished
# Get Data for :  ZKIN
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZKIN.csv  Saved
# Finished
# Get Data for :  ZLAB
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZLAB.csv  Saved
# Finished
# Get Data for :  ZM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZM.csv  Saved
# Finished
# Get Data for :  ZNH
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZNH.csv  Saved
# Finished
# Get Data for :  ZNTL
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZNTL.csv  Saved
# Finished
# Get Data for :  ZOM
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZOM.csv  Saved
# Finished
# Get Data for :  ZS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZS.csv  Saved
# Finished
# Get Data for :  ZT
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZT.csv  Saved
# Finished
# Get Data for :  ZTAQU
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZTAQU.csv  Saved
# Finished
# Get Data for :  ZTAQW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZTAQW.csv  Saved
# Finished
# Get Data for :  ZTEK
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZTEK.csv  Saved
# Finished
# Get Data for :  ZTO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZTO.csv  Saved
# Finished
# Get Data for :  ZTR
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZTR.csv  Saved
# Finished
# Get Data for :  ZTS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZTS.csv  Saved
# Finished
# Get Data for :  ZUMZ
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZUMZ.csv  Saved
# Finished
# Get Data for :  ZUO
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZUO.csv  Saved
# Finished
# Get Data for :  ZVIA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZVIA.csv  Saved
# Finished
# Get Data for :  ZVSA
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZVSA.csv  Saved
# Finished
# Get Data for :  ZVSAW
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZVSAW.csv  Saved
# Finished
# Get Data for :  ZWS
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZWS.csv  Saved
# Finished
# Get Data for :  ZYME
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZYME.csv  Saved
# Finished
# Get Data for :  ZYNE
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZYNE.csv  Saved
# Finished
# Get Data for :  ZYXI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ZYXI.csv  Saved
# Finished

# %%
# missing = ["SAND", "FEI", "ETX"]
# for x in missing:
#     save_to_csv_from_yahoo(DIRECTORY, x)
# print("Finished")
# Out:
# Get Data for :  SAND
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/SAND.csv  Saved
# Get Data for :  FEI
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/FEI.csv  Saved
# Get Data for :  ETX
# C:/Users/Mesh/Desktop/PythonFinance/Python4Finance/BigSectorStocks/ETX.csv  Saved
# Finished
